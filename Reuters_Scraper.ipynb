# %%
#Packages
#--Web scraping packages
from bs4 import BeautifulSoup
import requests
#Pandas/numpy for data manipulation
import pandas as pd
import numpy as np

# %%
#load URLs we want to scrape into an array
BASE_URL = [
'http://www.reuters.com/finance/stocks/company-officers/APD',
'http://www.reuters.com/finance/stocks/company-officers/LING.DE',
'http://www.reuters.com/finance/stocks/company-officers/PX'
]

# %%
#loading empty array for board members
board_members = []
#Loop through our URLs we loaded above
for b in BASE_URL:
    html = requests.get(b).text
    soup = BeautifulSoup(html, "html.parser")
    #identify table we want to scrape
    officer_table = soup.find('table', {"class" : "dataTable"})
    #try clause to skip any companies with missing/empty board member tables
    try:
    #loop through table, grab each of the 4 columns shown (try one of the links yourself to see the layout)
        for row in officer_table.find_all('tr'):
            cols = row.find_all('td')
            if len(cols) == 4:
                board_members.append((b, cols[0].text.strip(), cols[1].text.strip(), cols[2].text.strip(), cols[3].text.strip()))
    except: pass

# %%
#convert output to new array, check length
board_array = np.asarray(board_members)
len(board_array)
# Out:
# 48

# %%
#convert new array to dataframe
df = pd.DataFrame(board_array)

# %%
#rename columns, check output
df.columns = ['URL', 'Name', 'Age','Year Joined', 'Title']
df
# Out:
#                                                   URL                    Name  \
# 0   http://www.reuters.com/finance/stocks/company-...       Seifollah Ghasemi
# 1   http://www.reuters.com/finance/stocks/company-...          Michael Crocco
# 2   http://www.reuters.com/finance/stocks/company-...          Jennifer Grant
# 3   http://www.reuters.com/finance/stocks/company-...          Victoria Brifo
# 4   http://www.reuters.com/finance/stocks/company-...              Sean Major
# 5   http://www.reuters.com/finance/stocks/company-...         Corning Painter
# 6   http://www.reuters.com/finance/stocks/company-...            Samir Serhan
# 7   http://www.reuters.com/finance/stocks/company-...          Russell Flugel
# 8   http://www.reuters.com/finance/stocks/company-...         Chadwick Deaton
# 9   http://www.reuters.com/finance/stocks/company-...            Susan Carter
# 10  http://www.reuters.com/finance/stocks/company-...           Charles Cogut
# 11  http://www.reuters.com/finance/stocks/company-...            Hing-Yuen Ho
# 12  http://www.reuters.com/finance/stocks/company-...        Margaret McGlynn
# 13  http://www.reuters.com/finance/stocks/company-...           Edward Monser
# 14  http://www.reuters.com/finance/stocks/company-...           Matthew Paull
# 15  http://www.reuters.com/finance/stocks/company-...             Simon Moore
# 16  http://www.reuters.com/finance/stocks/company-...        Wolfgang Reitzle
# 17  http://www.reuters.com/finance/stocks/company-...            Aldo Belloni
# 18  http://www.reuters.com/finance/stocks/company-...        Franz Fehrenbach
# 19  http://www.reuters.com/finance/stocks/company-...             Gernot Hahl
# 20  http://www.reuters.com/finance/stocks/company-...          Sven Schneider
# 21  http://www.reuters.com/finance/stocks/company-...         Christian Bruch
# 22  http://www.reuters.com/finance/stocks/company-...            Bernd Eulitz
# 23  http://www.reuters.com/finance/stocks/company-...            Sanjiv Lamba
# 24  http://www.reuters.com/finance/stocks/company-...         Clemens Boersig
# 25  http://www.reuters.com/finance/stocks/company-...  Ann-Kristin Achleitner
# 26  http://www.reuters.com/finance/stocks/company-...          Anke Couturier
# 27  http://www.reuters.com/finance/stocks/company-...           Thomas Enders
# 28  http://www.reuters.com/finance/stocks/company-...      Hans-Peter Kaballo
# 29  http://www.reuters.com/finance/stocks/company-...          Martin Kimmich
# 30  http://www.reuters.com/finance/stocks/company-...       Victoria Ossadnik
